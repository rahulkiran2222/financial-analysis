# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("financial_data.csv")

df
df['Revenue Growth (%)'] = df.groupby('Company')['Total Revenue'].pct_change() * 100

df['Net Income Growth (%)'] = df.groupby('Company')['Net Income'].pct_change() * 100

df
summary = df.groupby("Company").mean(numeric_only=True)

summary
companies = df['Company'].unique()

for company in companies:
    company_df = df[df['Company'] == company]
    
    plt.figure(figsize=(6,4))
    plt.plot(company_df['Year'], company_df['Total Revenue'], marker='o')
    plt.title(f"{company} Revenue Trend")
    plt.xlabel("Year")
    plt.ylabel("Revenue")
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Financial Analysis of Microsoft, Apple, and Tesla
#
# This notebook analyzes financial trends from the last three fiscal years using data extracted from 10-K reports.
# # Key Findings
#
# - Microsoft showed stable revenue growth.
# - Apple maintained strong profitability.
# - Tesla experienced rapid revenue expansion.
# - Operating cash flow remained positive across all companies.
